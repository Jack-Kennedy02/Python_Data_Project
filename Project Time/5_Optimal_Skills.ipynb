# %%
# Importing Libraries

import ast
import pandas as pd
import matplotlib.pyplot as plt
# !pip install datasets
from datasets import load_dataset
import seaborn as sns
# !pip install adjustText

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)
# Out:
# Requirement already satisfied: datasets in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (2.19.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: multiprocess in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (0.24.6)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from aiohttp->datasets) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from aiohttp->datasets) (1.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Requirement already satisfied: adjustText in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: numpy in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from adjustText) (1.26.4)
# Requirement already satisfied: matplotlib in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from adjustText) (3.9.2)
# Requirement already satisfied: scipy in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from adjustText) (1.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from matplotlib->adjustText) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from matplotlib->adjustText) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from matplotlib->adjustText) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from matplotlib->adjustText) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from matplotlib->adjustText) (24.2)
# Requirement already satisfied: pillow>=8 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from matplotlib->adjustText) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from matplotlib->adjustText) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from matplotlib->adjustText) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib->adjustText) (1.16.0)

# %%
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

df_DA_US = df_DA_US.dropna(subset=['salary_year_avg'])

df_DA_US_exploded = df_DA_US.explode('job_skills')

df_DA_US_exploded[['salary_year_avg', 'job_skills']].head(5)
# Out:
#      salary_year_avg job_skills
# 109          89000.0     python
# 109          89000.0          r
# 109          89000.0    alteryx
# 109          89000.0    tableau
# 180          90250.0      excel

# %%
df_DA_skills = df_DA_US_exploded.groupby('job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by='count', ascending=False)

df_DA_skills = df_DA_skills.rename(columns={'count': 'skill_count', 'median': 'median_salary'})

DA_job_count = len(df_DA_US)

df_DA_skills['skill_percent'] = df_DA_skills['skill_count'] / DA_job_count * 100

skill_percent = 5

df_DA_skills_high_demand = df_DA_skills[df_DA_skills['skill_percent'] > skill_percent]

df_DA_skills_high_demand
# Out:
#             skill_count  median_salary  skill_percent
# job_skills
# sql                2508       91000.00      57.655172
# excel              1808       84392.00      41.563218
# python             1431       97500.00      32.896552
# tableau            1364       92875.00      31.356322
# sas                 926       90000.00      21.287356
# r                   893       92500.00      20.528736
# power bi            838       90000.00      19.264368
# powerpoint          462       85000.00      10.620690
# word                461       81194.75      10.597701
# sql server          286       92500.00       6.574713
# oracle              274       96923.75       6.298851
# go                  224       90000.00       5.149425

# %%
from adjustText import adjust_text

df_DA_skills_high_demand.plot(kind='scatter', x='skill_percent', y='median_salary')

# Prepare texts for adjust Text

texts=[]
for i, txt in enumerate(df_DA_skills_high_demand.index):
    texts.append(plt.text(df_DA_skills_high_demand['skill_percent'].iloc[i], df_DA_skills_high_demand['median_salary'].iloc[i], str(df_DA_skills_high_demand.index[i])))

# Adjust text to avoid overlap
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

# Set axis labels, title, and legend
plt.xlabel('Percent of Data Analyst Jobs')
plt.ylabel('Median Yearly Salary')
plt.title('Most Optimal Skills for Data Analysts in the US')


from matplotlib.ticker import PercentFormatter
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))
ax.xaxis.set_major_formatter(PercentFormatter(decimals=0))

# Adjust layout and display plot
plt.tight_layout()
plt.show()

# %%
#Optional Piece

df_technology = df['job_type_skills'].copy()

# remove duplicates
df_technology = df_technology.drop_duplicates()

# remove NaN values
df_technology = df_technology.dropna()

# combine all dictionaries into one
technology_dict = {}

for row in df_technology:
    row_dict = ast.literal_eval(row)  # convert string to dictionary
    for key, value in row_dict.items():  # Iterate through the items of row_dict
        if key in technology_dict:
            technology_dict[key] += value  # If key exists, add the value
        else:
            technology_dict[key] = value  # If key doesn't exist, create it

# remove duplicates by converting values to set then back to list
for key, value in technology_dict.items():
    technology_dict[key] = list(set(value))

technology_dict
# Out:
# {'analyst_tools': ['power bi',
#   'excel',
#   'qlik',
#   'powerpoint',
#   'sharepoint',
#   'datarobot',
#   'powerbi',
#   'cognos',
#   'spss',
#   'esquisse',
#   'msaccess',
#   'ssrs',
#   'microstrategy',
#   'word',
#   'visio',
#   'outlook',
#   'sheets',
#   'ms access',
#   'nuix',
#   'looker',
#   'sas',
#   'dax',
#   'splunk',
#   'alteryx',
#   'ssis',
#   'tableau',
#   'spreadsheet',
#   'sap'],
#  'programming': ['visual basic',
#   'swift',
#   'r',
#   'clojure',
#   'css',
#   'vb.net',
#   'no-sql',
#   'visualbasic',
#   'delphi',
#   'powershell',
#   'apl',
#   'solidity',
#   'pascal',
#   'assembly',
#   'php',
#   'f#',
#   'sass',
#   'lisp',
#   'go',
#   'vba',
#   'fortran',
#   'erlang',
#   'haskell',
#   'cobol',
#   'ocaml',
#   'c#',
#   'sql',
#   'shell',
#   'nosql',
#   'matlab',
#   'python',
#   'rust',
#   'julia',
#   'bash',
#   'scala',
#   'mongo',
#   'java',
#   'crystal',
#   'perl',
#   'mongodb',
#   'c++',
#   'elixir',
#   'sas',
#   'javascript',
#   'objective-c',
#   'ruby',
#   'lua',
#   'golang',
#   't-sql',
#   'kotlin',
#   'dart',
#   'groovy',
#   'typescript',
#   'html',
#   'c'],
#  'cloud': ['colocation',
#   'vmware',
#   'firebase',
#   'redshift',
#   'gcp',
#   'ovh',
#   'bigquery',
#   'azure',
#   'oracle',
#   'openstack',
#   'watson',
#   'linode',
#   'aurora',
#   'digitalocean',
#   'aws',
#   'databricks',
#   'snowflake',
#   'ibm cloud',
#   'heroku'],
#  'libraries': ['spark',
#   'electron',
#   'rshiny',
#   'jupyter',
#   'airflow',
#   'chainer',
#   'tidyverse',
#   'ggplot2',
#   'ionic',
#   'cordova',
#   'plotly',
#   'hugging face',
#   'nltk',
#   'huggingface',
#   'flutter',
#   'dplyr',
#   'graphql',
#   'dlib',
#   'opencv',
#   'capacitor',
#   'qt',
#   'tidyr',
#   'gdpr',
#   'kafka',
#   'tensorflow',
#   'matplotlib',
#   'scikit-learn',
#   'pytorch',
#   'mlpack',
#   'theano',
#   'selenium',
#   'shogun',
#   'gtx',
#   'seaborn',
#   'hadoop',
#   'mlr',
#   'spring',
#   'keras',
#   'pandas',
#   'react',
#   'pyspark',
#   'numpy',
#   'mxnet',
#   'xamarin'],
#  'other': ['flow',
#   'atlassian',
#   'kubernetes',
#   'terraform',
#   'github',
#   'homebrew',
#   'unity',
#   'puppet',
#   'terminal',
#   'gitlab',
#   'docker',
#   'bitbucket',
#   'svn',
#   'npm',
#   'codecommit',
#   'git',
#   'jenkins',
#   'ansible',
#   'yarn',
#   'unreal',
#   'pulumi',
#   'chef'],
#  'databases': ['postgresql',
#   'couchbase',
#   'mysql',
#   'redis',
#   'mongodb',
#   'couchdb',
#   'sqlserver',
#   'sqlite',
#   'firestore',
#   'firebase',
#   'sql server',
#   'cassandra',
#   'dynamodb',
#   'db2',
#   'elasticsearch',
#   'neo4j',
#   'mariadb'],
#  'os': ['redhat',
#   'centos',
#   'kali',
#   'linux',
#   'unix',
#   'fedora',
#   'windows',
#   'suse',
#   'debian',
#   'macos',
#   'ubuntu',
#   'wsl',
#   'arch'],
#  'async': ['jira',
#   'airtable',
#   'planner',
#   'asana',
#   'clickup',
#   'confluence',
#   'workfront',
#   'smartsheet',
#   'microsoft lists',
#   'wrike',
#   'trello',
#   'notion',
#   'monday.com',
#   'dingtalk',
#   'wimi'],
#  'webframeworks': ['blazor',
#   'vue.js',
#   'asp.net core',
#   'play framework',
#   'gatsby',
#   'node.js',
#   'rubyon rails',
#   'ruby on rails',
#   'vue',
#   'laravel',
#   'svelte',
#   'next.js',
#   'nuxt.js',
#   'express',
#   'flask',
#   'drupal',
#   'fastify',
#   'angular',
#   'phoenix',
#   'deno',
#   'node',
#   'symfony',
#   'ember.js',
#   'jquery',
#   'fastapi',
#   'asp.netcore',
#   'react.js',
#   'ruby',
#   'django',
#   'asp.net',
#   'angular.js'],
#  'sync': ['microsoft teams',
#   'twilio',
#   'zoom',
#   'symphony',
#   'google chat',
#   'unify',
#   'slack',
#   'ringcentral',
#   'wire',
#   'mattermost',
#   'rocketchat',
#   'webex']}

# %%
df_technology = pd.DataFrame(list(technology_dict.items()), columns=['technology', 'skills'])

df_technology = df_technology.explode('skills')

df_technology
# Out:
#        technology       skills
# 0   analyst_tools     power bi
# 0   analyst_tools        excel
# 0   analyst_tools         qlik
# 0   analyst_tools   powerpoint
# 0   analyst_tools   sharepoint
# ..            ...          ...
# 9            sync  ringcentral
# 9            sync         wire
# 9            sync   mattermost
# 9            sync   rocketchat
# 9            sync        webex
#
# [256 rows x 2 columns]

# %%
df_plot = df_DA_skills_high_demand.merge(df_technology, left_on='job_skills', right_on='skills')

# %%
# df_plot.plot(kind='scatter', x='skill_percent', y='median_salary')
sns.scatterplot(
    data=df_plot,
    x='skill_percent',
    y='median_salary',
    hue='technology'

)

sns.despine()
sns.set_theme(style='ticks')
# Prepare texts for adjust Text

texts=[]
for i, txt in enumerate(df_DA_skills_high_demand.index):
    texts.append(plt.text(df_DA_skills_high_demand['skill_percent'].iloc[i], df_DA_skills_high_demand['median_salary'].iloc[i], str(df_DA_skills_high_demand.index[i])))

# Adjust text to avoid overlap
adjust_text(texts, arrowprops=dict(arrowstyle='->', color='gray'))

# Set axis labels, title, and legend
plt.xlabel('Percent of Data Analyst Jobs')
plt.ylabel('Median Yearly Salary')
plt.title('Most Optimal Skills for Data Analysts in the US')


from matplotlib.ticker import PercentFormatter
ax = plt.gca()
ax.yaxis.set_major_formatter(plt.FuncFormatter(lambda y, pos: f'${int(y/1000)}K'))
ax.xaxis.set_major_formatter(PercentFormatter(decimals=0))

# Adjust layout and display plot
plt.tight_layout()
plt.show()
