# %%
## Importing Libraries

# !pip install datasets
import ast
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datasets import load_dataset

# Loading Data
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

#Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval if pd.notna(x) else x)
# Out:
# Requirement already satisfied: datasets in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (2.19.1)
# Requirement already satisfied: filelock in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (17.0.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (2.2.3)
# Requirement already satisfied: requests>=2.19.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.62.1 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (4.66.5)
# Requirement already satisfied: xxhash in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (2.0.2)
# Requirement already satisfied: multiprocess in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (0.70.15)
# Requirement already satisfied: fsspec<=2024.3.1,>=2023.1.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from fsspec[http]<=2024.3.1,>=2023.1.0->datasets) (2024.3.1)
# Requirement already satisfied: aiohttp in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (3.11.10)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (0.24.6)
# Requirement already satisfied: packaging in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from aiohttp->datasets) (2.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from aiohttp->datasets) (24.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from aiohttp->datasets) (1.5.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from aiohttp->datasets) (6.1.0)
# Requirement already satisfied: propcache>=0.2.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from aiohttp->datasets) (0.2.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from aiohttp->datasets) (1.18.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from huggingface-hub>=0.21.2->datasets) (4.12.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from requests>=2.19.0->datasets) (2024.12.14)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/envs/Python_Data_Project/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)

# %%
## Filtering for DA US dataframe

df_DA_US = df[(df['job_country'] == 'United States') & (df['job_title_short'] == 'Data Analyst')]

df_plot = df_DA_US['job_location'].value_counts().head(10).to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='job_location', hue='count', palette='dark:b_r')
sns.despine()
plt.title("Number of Jobs per Job Title")
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()

# %%
#rewrite the above with a for loop

dict_column = {
'job_work_from_home': ' Work from Home Offered',
'job_no_degree_mention': 'Degree Requirement',
'job_health_insurance': 'Health Insurance Offered'
}

fig, ax = plt.subplots(1, 3)
fig.set_size_inches((12, 5))

for i, (column,title) in enumerate(dict_column.items()):
    ax[i].pie(df_DA_US[column].value_counts(), labels=['False', 'True'], autopct='%1.1f%%', startangle=90)
    ax[i].set_title(title)
plt.show()

# %%
df_plot = df_DA_US['company_name'].value_counts().head(10).to_frame()

sns.set_theme(style='ticks')
sns.barplot(data=df_plot, x='count', y='company_name', hue='count', palette='dark:b_r')
sns.despine()
plt.title("Number of Jobs per Job Title")
plt.xlabel('Number of Jobs')
plt.ylabel('')
plt.show()
